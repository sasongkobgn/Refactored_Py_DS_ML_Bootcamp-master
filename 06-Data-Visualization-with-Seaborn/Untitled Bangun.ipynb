# %% [markdown]
# seaborn adalah library yang digunakan untuk ploting seperti halnya maplotlib

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
# create some data 
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
# plot the data with Matplotlib defaults 
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# jika melihat scatter plot ini seperti teringat kerjaan skripsi! okay bagaimana kita bisa mengeplot data tersebut!

# %%
# okay kita berangkat kembali, 
# data = np.random.multivariate_normal([0, 0] [[5, 2], [2, 2]], size=2000)
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5);
# Out:
# C:\Users\sason\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   import sys

# %% [markdown]
# daripada kita menggunakan histogram kita lebih smooth mengestimasi mengguakna kernel desity estimation
# dimana yang dimiliki oleh seaborn,

# %%
for col in 'xy': 
    sns.kdeplot(data[col], shade=True)

# %% [markdown]
# jangan lupa mengimport seaborn!
#
#
# dibawah ini kita akan menggabugnkan histogram dan KDE,

# %%
sns.distplot(data['x'])
sns.distplot(data['y']); # always end with semicolon for data like this

# %%
data.head()
# Out:
#           x         y
# 0 -0.843494  0.191665
# 1  2.927277  1.609868
# 2  0.082923 -0.465957
# 3  2.210937 -0.213911
# 4  0.265748 -0.713709

# %%
#ketika menggunakan semicolon kita dapat mengabaikan warning 
sns.kdeplot(data); # dont forget semicolon

# %% [markdown]
# selanjutnya adalah kita bisa mengeplot data kita menjadi lebih baik lagi!

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde');

# %% [markdown]
# sebuah joint distirburion plot dengan dua estimate density kernel.
# pengeplotan data sepertinya ini menjadi sangat menarik dan informatif

# %% [markdown]
# kamu masih banyak sekali yang salah dengan pennulisan kamu bisamegguakan visual studio agar lebih produktive!

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5);
